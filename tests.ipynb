# %%
import preferences
import curves
from importlib import reload

reload(curves);

# %%
data = curves.Data()
data.load(preferences.INPUT_PATH)

# data.plot_avgs_angle(show=True)
# data.plot_all_temporal(reynolds=50000)
data.plot_all_individual()
# data.plot_avgs_angle()
