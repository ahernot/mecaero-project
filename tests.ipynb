# %%
import preferences
import curves
from importlib import reload

reload(curves);

# %%
data = curves.Data()
data.load(preferences.INPUT_PATH)

# data.plot_avgs_angle(show=True)
data.plot(show=True)
