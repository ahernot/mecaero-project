# %%
import preferences
import curves
from importlib import reload

# %%
reload(curves);

# %%
data = curves.Data(reynolds=75000)
data.load(preferences.INPUT_PATH)

# %%
data.plot_comparison(save=True)
