# %%
import preferences
import curves
from importlib import reload

# %%
reload(curves);

# %%
data = curves.Data()
data.load(preferences.INPUT_PATH)

data.plot_all_temporal(save=True, figsize=(100, 50))
data.plot_all_individual(save=True)
data.plot_avgs_angle(save=True)
